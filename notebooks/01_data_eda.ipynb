# %% [markdown]
# # Week 1 — Data EDA\n

# %%
import pandas as pd\nimport matplotlib.pyplot as plt\ndf=pd.read_csv('../data/patient_records.csv')\ndf.shape, df.dtypes\n

# %%
df.isna().sum()\n

# %%
df[['Age','Biomarker_Level','Vaccine_Dose_mcg']].hist(figsize=(10,4)); plt.tight_layout()\n

# %%
df['Reaction_Score'].value_counts().plot(kind='bar',title='Reaction Score Class Balance'); plt.tight_layout()\n
